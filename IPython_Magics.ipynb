# %%
# %alias_magic t timeit
# Out:
# Created `%t` as an alias for `%timeit`.
# Created `%%t` as an alias for `%%timeit`.

# %%
# %t -n1 pass
# Out:
# 1 loop, best of 3: 110 ns per loop

# %%
# %alias_magic --line whereami pwd
# Out:
# Created `%whereami` as an alias for `%pwd`.

# %%
# %whereami
# Out:
# '/content'

# %%
# %config
# Out:
# Available objects for config:
#      Shell
#      HistoryManager
#      PrefilterManager
#      IPCompleter
#      DisplayFormatter
#      MagicsManager
#      ScriptMagics
#      AliasManager
#      IPKernelApp
#      InlineBackend
#      StoreMagics
#      StoreMagics

# %%
# %config IPCompleter
# Out:
# IPCompleter options
# -----------------
# IPCompleter.backslash_combining_completions=<Bool>
#     Current: True
#     Enable unicode completions, e.g. \alpha<tab> . Includes completion of latex
#     commands, unicode names, and expanding unicode characters back to latex
#     commands.
# IPCompleter.greedy=<Bool>
#     Current: False
#     Activate greedy completion PENDING DEPRECTION. this is now mostly taken care
#     of with Jedi.
#     This will enable completion on elements of lists, results of function calls,
#     etc., but can be unsafe because the code is actually evaluated on TAB.
# IPCompleter.limit_to__all__=<Bool>
#     Current: False
#     DEPRECATED as of version 5.0.
#     Instruct the completer to use __all__ for the completion
#     Specifically, when completing on ``object.<tab>``.
#     When True: only those names in obj.__all__ will be included.
#     When False [default]: the __all__ attribute is ignored
# IPCompleter.merge_completions=<Bool>
# ...

# %%
# %config IPCompleter.greedy = True

# %%
# %dirs
# Out:
# []

# %%
# %dhist
# Out:
# Directory history (kept in _dh)
# 0: /content

# %%
# %doctest_mode
# Out:
# Exception reporting mode: Plain
# Doctest mode is: ON

# %%
# %env
# Out:
# {'ENV': '/root/.bashrc', 'GCS_READ_CACHE_BLOCK_SIZE_MB': '16', 'CLOUDSDK_CONFIG': '/content/.config', 'CUDA_VERSION': '10.0.130', 'PATH': '/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin:/opt/bin', 'HOME': '/root', 'LD_LIBRARY_PATH': '/usr/local/nvidia/lib:/usr/local/nvidia/lib64', 'LANG': 'en_US.UTF-8', 'SHELL': '/bin/bash', 'LIBRARY_PATH': '/usr/local/cuda/lib64/stubs', 'CUDA_PKG_VERSION': '10-0=10.0.130-1', 'SHLVL': '1', 'NCCL_VERSION': '2.4.7', 'NVIDIA_VISIBLE_DEVICES': 'all', 'TF_FORCE_GPU_ALLOW_GROWTH': 'true', 'DEBIAN_FRONTEND': 'noninteractive', 'CUDNN_VERSION': '7.6.2.24', 'LAST_FORCED_REBUILD': '20190507', 'JPY_PARENT_PID': '23', 'PYTHONPATH': '/env/python', 'DATALAB_SETTINGS_OVERRIDES': '{"kernelManagerProxyPort":6000,"kernelManagerProxyHost":"172.28.0.3","jupyterArgs":["--ip=\\"172.28.0.2\\""]}', 'NO_GCE_CHECK': 'True', 'GLIBCXX_FORCE_NEW': '1', 'NVIDIA_DRIVER_CAPABILITIES':
# ...

# %%
#  integration of Qt5 eventLoops
# %gui qt5

# %%
# %history -n
# Out:
#    1: alias bracket echo "Input in brackets: <%l>"
#    2: alias bracket echo "Input in brackets: <%l>"
#    3:
# alias bracket echo "Input in brackets: <%l>"
# bracket hello world
#    4: alias parts echo first %s second %s
#    5: %parts A B
#    6: alias show echo
#    7:
# PATH='A Python string'
# show $PATH
#    8:
# PATH='A Python string'
# show PATH
#    9: %alias_magic t timeit
#   10: %t -n1 pass
#   11: %alias_magic --line whereami pwd
#   12: %whereami
#   13: %colors nocolor
#   14: %config
#   15: %config IPCompleter
#   16: %config IPCompleter.greedy = True
#   17: %dirs
#   18: %dhist
#   19: %doctest_mode
#   20: %edit
#   21: edit
#   22: %env
#   23: %env['ENV']
#   24: %env[ENV]
#   25: %env["ENV"]
#   26: toto = %env
#   27: toto['ENV']
#   28: %gui
#   29: %gui qt5
#   30: %gui qt5
#   31: %history
#   32: %history -n

# %%
from IPython.display import set_matplotlib_formats

# %%
set_matplotlib_formats('pdf', 'svg')

# %%
# %config InlineBackend.print_figure_kwargs = {'bbox_inches':None}

# %%
# %matplotlib inline

# %%
# %matplotlib --list
# Out:
# Available matplotlib backends: ['tk', 'gtk', 'gtk3', 'wx', 'qt4', 'qt5', 'qt', 'osx', 'nbagg', 'notebook', 'agg', 'inline', 'ipympl', 'widget']

# %%
# %notebook sauvegarde.ipynb

# %%
import pandas
# %pdef pandas.read_csv
# Out:
#  pandas.read_csv(filepath_or_buffer, sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, iterator=False, chunksize=None, compression='infer', thousands=None, decimal=b'.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, dialect=None, tupleize_cols=None, error_bad_lines=True, warn_bad_lines=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)

# %%
import datetime
# %pdoc datetime

# %%
# %quickref

# %%
# %who
# Out:
# datetime	 pandas	 pi	 set_matplotlib_formats	 toto	 urllib

# %%
# %xdel toto

# %%
# %%script bash
# for i in 1 2 3; do
#   echo $i
#   done
# Out:
# 1
# 2
# 3

# %%
pip install sqlalchemy

# %%
pip install ipython-sql

# %%
# %load_ext sql

# %%
# %sql sqlite://
# Out:
# 'Connected: @None'

# %%
# %%sql
# CREATE TABLE writer (first_name, last_name, year_of_death);
# INSERT INTO writer VALUES('William','Shakespeare',1616);
# INSERT INTO writer VALUES('Bethold', 'Brecht', 1956);
# Out:
#  * sqlite://
# Done.
# 1 rows affected.
# 1 rows affected.
# []

# %%
result = %sql select * from writer
# Out:
#  * sqlite://
# Done.

# %%
dataframe = result.DataFrame()

# %%
dataframe
# Out:
#   first_name    last_name  year_of_death
# 0    William  Shakespeare           1616
# 1    Bethold       Brecht           1956

# %%
dataframe.to_csv('dataframe.csv')

# %%
restore = pandas.read_csv('dataframe.csv')

# %%
restore
# Out:
#    Unnamed: 0 first_name    last_name  year_of_death
# 0           0    William  Shakespeare           1616
# 1           1    Bethold       Brecht           1956

# %%
# %config SqlMagic
# Out:
# SqlMagic options
# --------------
# SqlMagic.autocommit=<Bool>
#     Current: True
#     Set autocommit mode
# SqlMagic.autolimit=<Int>
#     Current: 0
#     Automatically limit the size of the returned result sets
# SqlMagic.autopandas=<Bool>
#     Current: False
#     Return Pandas DataFrames instead of regular result sets
# SqlMagic.column_local_vars=<Bool>
#     Current: False
#     Return data into local variables from column names
# SqlMagic.displaylimit=<Int>
#     Current: None
#     Automatically limit the number of rows displayed (full result set is still
#     stored)
# SqlMagic.dsn_filename=<Unicode>
#     Current: 'odbc.ini'
#     Path to DSN file. When the first argument is of the form [section], a
#     sqlalchemy connection string is formed from the matching section in the DSN
#     file.
# SqlMagic.feedback=<Bool>
#     Current: True
#     Print number of rows affected by DML
# SqlMagic.short_errors=<Bool>
#     Current: True
# ...
