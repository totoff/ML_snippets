# %%
# !pip install h2o
# Out:
# Collecting h2o
#   Downloading https://files.pythonhosted.org/packages/6b/d1/aaa74df4716b2454d6034261807ef3855d014862c801f0e9b803b568006d/h2o-3.28.0.1.tar.gz (123.4MB)
#      |████████████████████████████████| 123.4MB 91kB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from h2o) (2.21.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.6/dist-packages (from h2o) (0.8.6)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from h2o) (0.16.0)
# Collecting colorama>=0.3.8
#   Downloading https://files.pythonhosted.org/packages/c9/dc/45cdef1b4d119eb96316b3117e6d5708a08029992b2fee2c143c7a0a5cc5/colorama-0.4.3-py2.py3-none-any.whl
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->h2o) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->h2o) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->h2o) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->h2o) (1.24.3)
# Building wheels for collected packages: h2o
#   Building wheel for h2o (setup.py) ... done
#   Created wheel for h2o: filename=h2o-3.28.0.1-py2.py3-none-any.whl size=123410554 sha256=ce36a8a62f8a3b9c1a922265932c2a0e0206b2901e7e20b5b7e4981e3e9feb95
#   Stored in directory: /root/.cache/pip/wheels/ff/82/f4/3fe9c895b93c53b25ae44dc44aa54dad571c711f48bc485fe9
# Successfully built h2o
# Installing collected packages: colorama, h2o
# Successfully installed colorama-0.4.3 h2o-3.28.0.1

# %%
import pandas as pd
import numpy as np
import h2o
pd.set_option('display.width', 5000)

# %%
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 ..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "11.0.5" 2019-10-15; OpenJDK Runtime Environment (build 11.0.5+10-post-Ubuntu-0ubuntu1.118.04); OpenJDK 64-Bit Server VM (build 11.0.5+10-post-Ubuntu-0ubuntu1.118.04, mixed mode, sharing)
#   Starting server from /usr/local/lib/python3.6/dist-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmprjwhqt_m
#   JVM stdout: /tmp/tmprjwhqt_m/h2o_unknownUser_started_from_python.out
#   JVM stderr: /tmp/tmprjwhqt_m/h2o_unknownUser_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  ------------------------------------------------------------------
# H2O cluster uptime:         02 secs
# H2O cluster timezone:       Etc/UTC
# H2O data parsing timezone:  UTC
# H2O cluster version:        3.28.0.1
# H2O cluster version age:    16 days
# H2O cluster name:           H2O_from_python_unknownUser_jilxmc
# H2O cluster total nodes:    1
# H2O cluster free memory:    3 Gb
# H2O cluster total cores:    2
# H2O cluster allowed cores:  2
# H2O cluster status:         accepting new members, healthy
# H2O connection url:         http://127.0.0.1:54321
# H2O connection proxy:       {'http': None, 'https': None}
# H2O internal security:      False
# H2O API Extensions:         Amazon S3, XGBoost, Algos, AutoML, Core V3, TargetEncoder, Core V4
# Python version:             3.6.9 final
# --------------------------  ------------------------------------------------------------------

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/00222/bank-additional.zip
# Out:
# --2020-01-02 11:15:25--  https://archive.ics.uci.edu/ml/machine-learning-databases/00222/bank-additional.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 444572 (434K) [application/x-httpd-php]
# Saving to: ‘bank-additional.zip’
#
# bank-additional.zip 100%[===================>] 434.15K  --.-KB/s    in 0.1s
#
# 2020-01-02 11:15:26 (2.92 MB/s) - ‘bank-additional.zip’ saved [444572/444572]

# %%
# !unzip bank-additional.zip
# Out:
# Archive:  bank-additional.zip
#    creating: bank-additional/
#   inflating: bank-additional/.DS_Store
#    creating: __MACOSX/
#    creating: __MACOSX/bank-additional/
#   inflating: __MACOSX/bank-additional/._.DS_Store
#   inflating: bank-additional/.Rhistory
#   inflating: bank-additional/bank-additional-full.csv
#   inflating: bank-additional/bank-additional-names.txt
#   inflating: bank-additional/bank-additional.csv
#   inflating: __MACOSX/._bank-additional

# %%
bank_df = h2o.upload_file("bank-additional/bank-additional-full.csv")
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
bank_df
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  age</th><th>job        </th><th>marital  </th><th>education          </th><th>default  </th><th>housing  </th><th>loan  </th><th>contact  </th><th>month  </th><th>day_of_week  </th><th style="text-align: right;">  duration</th><th style="text-align: right;">  campaign</th><th style="text-align: right;">  pdays</th><th style="text-align: right;">  previous</th><th>poutcome   </th><th style="text-align: right;">  emp.var.rate</th><th style="text-align: right;">  cons.price.idx</th><th style="text-align: right;">  cons.conf.idx</th><th style="text-align: right;">  euribor3m</th><th style="text-align: right;">  nr.employed</th><th>y  </th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">   56</td><td>housemaid  </td><td>married  </td><td>basic.4y           </td><td>no       </td><td>no       </td><td>no    </td><td>telephone</td><td>may    </td><td>mon          </td><td style="text-align: right;">       261</td><td style="text-align: right;">         1</td><td style="text-align: right;">    999</td><td style="text-align: right;">         0</td><td>nonexistent</td><td style="text-align: right;">           1.1</td><td style="text-align: right;">          93.994</td><td style="text-align: right;">          -36.4</td><td style="text-align: right;">      4.857</td><td style="text-align: right;">         5191</td><td>no </td></tr>
# <tr><td style="text-align: right;">   57</td><td>services   </td><td>married  </td><td>high.school        </td><td>unknown  </td><td>no       </td><td>no    </td><td>telephone</td><td>may    </td><td>mon          </td><td style="text-align: right;">       149</td><td style="text-align: right;">         1</td><td style="text-align: right;">    999</td><td style="text-align: right;">         0</td><td>nonexistent</td><td style="text-align: right;">           1.1</td><td style="text-align: right;">          93.994</td><td style="text-align: right;">          -36.4</td><td style="text-align: right;">      4.857</td><td style="text-align: right;">         5191</td><td>no </td></tr>
# <tr><td style="text-align: right;">   37</td><td>services   </td><td>married  </td><td>high.school        </td><td>no       </td><td>yes      </td><td>no    </td><td>telephone</td><td>may    </td><td>mon          </td><td style="text-align: right;">       226</td><td style="text-align: right;">         1</td><td style="text-align: right;">    999</td><td style="text-align: right;">         0</td><td>nonexistent</td><td style="text-align: right;">           1.1</td><td style="text-align: right;">          93.994</td><td style="text-align: right;">          -36.4</td><td style="text-align: right;">      4.857</td><td style="text-align: right;">         5191</td><td>no </td></tr>
# <tr><td style="text-align: right;">   40</td><td>admin.     </td><td>married  </td><td>basic.6y           </td><td>no       </td><td>no       </td><td>no    </td><td>telephone</td><td>may    </td><td>mon          </td><td style="text-align: right;">       151</td><td style="text-align: right;">         1</td><td style="text-align: right;">    999</td><td style="text-align: right;">         0</td><td>nonexistent</td><td style="text-align: right;">           1.1</td><td style="text-align: right;">          93.994</td><td style="text-align: right;">          -36.4</td><td style="text-align: right;">      4.857</td><td style="text-align: right;">         5191</td><td>no </td></tr>
# <tr><td style="text-align: right;">   56</td><td>services   </td><td>married  </td><td>high.school        </td><td>no       </td><td>no       </td><td>yes   </td><td>telephone</td><td>may    </td><td>mon          </td><td style="text-align: right;">       307</td><td style="text-align: right;">         1</td><td style="text-align: right;">    999</td><td style="text-align: right;">         0</td><td>nonexistent</td><td style="text-align: right;">           1.1</td><td style="text-align: right;">          93.994</td><td style="text-align: right;">          -36.4</td><td style="text-align: right;">      4.857</td><td style="text-align: right;">         5191</td><td>no </td></tr>
# <tr><td style="text-align: right;">   45</td><td>services   </td><td>married  </td><td>basic.9y           </td><td>unknown  </td><td>no       </td><td>no    </td><td>telephone</td><td>may    </td><td>mon          </td><td style="text-align: right;">       198</td><td style="text-align: right;">         1</td><td style="text-align: right;">    999</td><td style="text-align: right;">         0</td><td>nonexistent</td><td style="text-align: right;">           1.1</td><td style="text-align: right;">          93.994</td><td style="text-align: right;">          -36.4</td><td style="text-align: right;">      4.857</td><td style="text-align: right;">         5191</td><td>no </td></tr>
# <tr><td style="text-align: right;">   59</td><td>admin.     </td><td>married  </td><td>professional.course</td><td>no       </td><td>no       </td><td>no    </td><td>telephone</td><td>may    </td><td>mon          </td><td style="text-align: right;">       139</td><td style="text-align: right;">         1</td><td style="text-align: right;">    999</td><td style="text-align: right;">         0</td><td>nonexistent</td><td style="text-align: right;">           1.1</td><td style="text-align: right;">          93.994</td><td style="text-align: right;">          -36.4</td><td style="text-align: right;">      4.857</td><td style="text-align: right;">         5191</td><td>no </td></tr>
# <tr><td style="text-align: right;">   41</td><td>blue-collar</td><td>married  </td><td>unknown            </td><td>unknown  </td><td>no       </td><td>no    </td><td>telephone</td><td>may    </td><td>mon          </td><td style="text-align: right;">       217</td><td style="text-align: right;">         1</td><td style="text-align: right;">    999</td><td style="text-align: right;">         0</td><td>nonexistent</td><td style="text-align: right;">           1.1</td><td style="text-align: right;">          93.994</td><td style="text-align: right;">          -36.4</td><td style="text-align: right;">      4.857</td><td style="text-align: right;">         5191</td><td>no </td></tr>
# <tr><td style="text-align: right;">   24</td><td>technician </td><td>single   </td><td>professional.course</td><td>no       </td><td>yes      </td><td>no    </td><td>telephone</td><td>may    </td><td>mon          </td><td style="text-align: right;">       380</td><td style="text-align: right;">         1</td><td style="text-align: right;">    999</td><td style="text-align: right;">         0</td><td>nonexistent</td><td style="text-align: right;">           1.1</td><td style="text-align: right;">          93.994</td><td style="text-align: right;">          -36.4</td><td style="text-align: right;">      4.857</td><td style="text-align: right;">         5191</td><td>no </td></tr>
# <tr><td style="text-align: right;">   25</td><td>services   </td><td>single   </td><td>high.school        </td><td>no       </td><td>yes      </td><td>no    </td><td>telephone</td><td>may    </td><td>mon          </td><td style="text-align: right;">        50</td><td style="text-align: right;">         1</td><td style="text-align: right;">    999</td><td style="text-align: right;">         0</td><td>nonexistent</td><td style="text-align: right;">           1.1</td><td style="text-align: right;">          93.994</td><td style="text-align: right;">          -36.4</td><td style="text-align: right;">      4.857</td><td style="text-align: right;">         5191</td><td>no </td></tr>
# </tbody>
# </table>

# %%
type(bank_df)
# Out:
# h2o.frame.H2OFrame

# %%
# show 6th row
print(bank_df[5,:])
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  age</th><th>job     </th><th>marital  </th><th>education  </th><th>default  </th><th>housing  </th><th>loan  </th><th>contact  </th><th>month  </th><th>day_of_week  </th><th style="text-align: right;">  duration</th><th style="text-align: right;">  campaign</th><th style="text-align: right;">  pdays</th><th style="text-align: right;">  previous</th><th>poutcome   </th><th style="text-align: right;">  emp.var.rate</th><th style="text-align: right;">  cons.price.idx</th><th style="text-align: right;">  cons.conf.idx</th><th style="text-align: right;">  euribor3m</th><th style="text-align: right;">  nr.employed</th><th>y  </th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">   45</td><td>services</td><td>married  </td><td>basic.9y   </td><td>unknown  </td><td>no       </td><td>no    </td><td>telephone</td><td>may    </td><td>mon          </td><td style="text-align: right;">       198</td><td style="text-align: right;">         1</td><td style="text-align: right;">    999</td><td style="text-align: right;">         0</td><td>nonexistent</td><td style="text-align: right;">           1.1</td><td style="text-align: right;">          93.994</td><td style="text-align: right;">          -36.4</td><td style="text-align: right;">      4.857</td><td style="text-align: right;">         5191</td><td>no </td></tr>
# </tbody>
# </table>

# %%
# show 6-7 rows
print(bank_df[5:7,:])
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  age</th><th>job     </th><th>marital  </th><th>education          </th><th>default  </th><th>housing  </th><th>loan  </th><th>contact  </th><th>month  </th><th>day_of_week  </th><th style="text-align: right;">  duration</th><th style="text-align: right;">  campaign</th><th style="text-align: right;">  pdays</th><th style="text-align: right;">  previous</th><th>poutcome   </th><th style="text-align: right;">  emp.var.rate</th><th style="text-align: right;">  cons.price.idx</th><th style="text-align: right;">  cons.conf.idx</th><th style="text-align: right;">  euribor3m</th><th style="text-align: right;">  nr.employed</th><th>y  </th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">   45</td><td>services</td><td>married  </td><td>basic.9y           </td><td>unknown  </td><td>no       </td><td>no    </td><td>telephone</td><td>may    </td><td>mon          </td><td style="text-align: right;">       198</td><td style="text-align: right;">         1</td><td style="text-align: right;">    999</td><td style="text-align: right;">         0</td><td>nonexistent</td><td style="text-align: right;">           1.1</td><td style="text-align: right;">          93.994</td><td style="text-align: right;">          -36.4</td><td style="text-align: right;">      4.857</td><td style="text-align: right;">         5191</td><td>no </td></tr>
# <tr><td style="text-align: right;">   59</td><td>admin.  </td><td>married  </td><td>professional.course</td><td>no       </td><td>no       </td><td>no    </td><td>telephone</td><td>may    </td><td>mon          </td><td style="text-align: right;">       139</td><td style="text-align: right;">         1</td><td style="text-align: right;">    999</td><td style="text-align: right;">         0</td><td>nonexistent</td><td style="text-align: right;">           1.1</td><td style="text-align: right;">          93.994</td><td style="text-align: right;">          -36.4</td><td style="text-align: right;">      4.857</td><td style="text-align: right;">         5191</td><td>no </td></tr>
# </tbody>
# </table>

# %%
# show first 4 columns from 6-7 rows
print(bank_df[5:7,0:4])
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  age</th><th>job     </th><th>marital  </th><th>education          </th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">   45</td><td>services</td><td>married  </td><td>basic.9y           </td></tr>
# <tr><td style="text-align: right;">   59</td><td>admin.  </td><td>married  </td><td>professional.course</td></tr>
# </tbody>
# </table>

# %%
# show job,education and y columns from 6-7 rows
print(bank_df[5:7, ['job', 'education', 'y']])
# Out:
# <table>
# <thead>
# <tr><th>job     </th><th>education          </th><th>y  </th></tr>
# </thead>
# <tbody>
# <tr><td>services</td><td>basic.9y           </td><td>no </td></tr>
# <tr><td>admin.  </td><td>professional.course</td><td>no </td></tr>
# </tbody>
# </table>

# %%
bank_df.shape
# Out:
# (41188, 21)

# %%
bank_df.describe()
# Out:
# Rows:41188
# Cols:21
# <table>
# <thead>
# <tr><th>       </th><th>age               </th><th>job        </th><th>marital  </th><th>education          </th><th>default  </th><th>housing  </th><th>loan  </th><th>contact  </th><th>month  </th><th>day_of_week  </th><th>duration          </th><th>campaign          </th><th>pdays             </th><th>previous           </th><th>poutcome   </th><th>emp.var.rate       </th><th>cons.price.idx    </th><th>cons.conf.idx     </th><th>euribor3m         </th><th>nr.employed       </th><th>y   </th></tr>
# </thead>
# <tbody>
# <tr><td>type   </td><td>int               </td><td>enum       </td><td>enum     </td><td>enum               </td><td>enum     </td><td>enum     </td><td>enum  </td><td>enum     </td><td>enum   </td><td>enum         </td><td>int               </td><td>int               </td><td>int               </td><td>int                </td><td>enum       </td><td>real               </td><td>real              </td><td>real              </td><td>real              </td><td>real              </td><td>enum</td></tr>
# <tr><td>mins   </td><td>17.0              </td><td>           </td><td>         </td><td>                   </td><td>         </td><td>         </td><td>      </td><td>         </td><td>       </td><td>             </td><td>0.0               </td><td>1.0               </td><td>0.0               </td><td>0.0                </td><td>           </td><td>-3.4               </td><td>92.201            </td><td>-50.8             </td><td>0.634             </td><td>4963.6            </td><td>    </td></tr>
# <tr><td>mean   </td><td>40.02406040594336 </td><td>           </td><td>         </td><td>                   </td><td>         </td><td>         </td><td>      </td><td>         </td><td>       </td><td>             </td><td>258.28501019714525</td><td>2.567592502670675 </td><td>962.4754540157295 </td><td>0.17296299893172756</td><td>           </td><td>0.08188550063125281</td><td>93.57566436826241 </td><td>-40.50260027192386</td><td>3.6212908128581027</td><td>5167.0359109449455</td><td>    </td></tr>
# <tr><td>maxs   </td><td>98.0              </td><td>           </td><td>         </td><td>                   </td><td>         </td><td>         </td><td>      </td><td>         </td><td>       </td><td>             </td><td>4918.0            </td><td>56.0              </td><td>999.0             </td><td>7.0                </td><td>           </td><td>1.4                </td><td>94.767            </td><td>-26.9             </td><td>5.045             </td><td>5228.1            </td><td>    </td></tr>
# <tr><td>sigma  </td><td>10.421249980934055</td><td>           </td><td>         </td><td>                   </td><td>         </td><td>         </td><td>      </td><td>         </td><td>       </td><td>             </td><td>259.27924883646455</td><td>2.7700135429023307</td><td>186.91090734474133</td><td>0.4949010798392893 </td><td>           </td><td>1.57095974051703   </td><td>0.5788400489541355</td><td>4.628197856174595 </td><td>1.7344474048512557</td><td>72.25152766825924 </td><td>    </td></tr>
# <tr><td>zeros  </td><td>0                 </td><td>           </td><td>         </td><td>                   </td><td>         </td><td>         </td><td>      </td><td>         </td><td>       </td><td>             </td><td>4                 </td><td>0                 </td><td>15                </td><td>35563              </td><td>           </td><td>0                  </td><td>0                 </td><td>0                 </td><td>0                 </td><td>0                 </td><td>    </td></tr>
# <tr><td>missing</td><td>0                 </td><td>0          </td><td>0        </td><td>0                  </td><td>0        </td><td>0        </td><td>0     </td><td>0        </td><td>0      </td><td>0            </td><td>0                 </td><td>0                 </td><td>0                 </td><td>0                  </td><td>0          </td><td>0                  </td><td>0                 </td><td>0                 </td><td>0                 </td><td>0                 </td><td>0   </td></tr>
# <tr><td>0      </td><td>56.0              </td><td>housemaid  </td><td>married  </td><td>basic.4y           </td><td>no       </td><td>no       </td><td>no    </td><td>telephone</td><td>may    </td><td>mon          </td><td>261.0             </td><td>1.0               </td><td>999.0             </td><td>0.0                </td><td>nonexistent</td><td>1.1                </td><td>93.994            </td><td>-36.4             </td><td>4.857             </td><td>5191.0            </td><td>no  </td></tr>
# <tr><td>1      </td><td>57.0              </td><td>services   </td><td>married  </td><td>high.school        </td><td>unknown  </td><td>no       </td><td>no    </td><td>telephone</td><td>may    </td><td>mon          </td><td>149.0             </td><td>1.0               </td><td>999.0             </td><td>0.0                </td><td>nonexistent</td><td>1.1                </td><td>93.994            </td><td>-36.4             </td><td>4.857             </td><td>5191.0            </td><td>no  </td></tr>
# <tr><td>2      </td><td>37.0              </td><td>services   </td><td>married  </td><td>high.school        </td><td>no       </td><td>yes      </td><td>no    </td><td>telephone</td><td>may    </td><td>mon          </td><td>226.0             </td><td>1.0               </td><td>999.0             </td><td>0.0                </td><td>nonexistent</td><td>1.1                </td><td>93.994            </td><td>-36.4             </td><td>4.857             </td><td>5191.0            </td><td>no  </td></tr>
# <tr><td>3      </td><td>40.0              </td><td>admin.     </td><td>married  </td><td>basic.6y           </td><td>no       </td><td>no       </td><td>no    </td><td>telephone</td><td>may    </td><td>mon          </td><td>151.0             </td><td>1.0               </td><td>999.0             </td><td>0.0                </td><td>nonexistent</td><td>1.1                </td><td>93.994            </td><td>-36.4             </td><td>4.857             </td><td>5191.0            </td><td>no  </td></tr>
# <tr><td>4      </td><td>56.0              </td><td>services   </td><td>married  </td><td>high.school        </td><td>no       </td><td>no       </td><td>yes   </td><td>telephone</td><td>may    </td><td>mon          </td><td>307.0             </td><td>1.0               </td><td>999.0             </td><td>0.0                </td><td>nonexistent</td><td>1.1                </td><td>93.994            </td><td>-36.4             </td><td>4.857             </td><td>5191.0            </td><td>no  </td></tr>
# <tr><td>5      </td><td>45.0              </td><td>services   </td><td>married  </td><td>basic.9y           </td><td>unknown  </td><td>no       </td><td>no    </td><td>telephone</td><td>may    </td><td>mon          </td><td>198.0             </td><td>1.0               </td><td>999.0             </td><td>0.0                </td><td>nonexistent</td><td>1.1                </td><td>93.994            </td><td>-36.4             </td><td>4.857             </td><td>5191.0            </td><td>no  </td></tr>
# <tr><td>6      </td><td>59.0              </td><td>admin.     </td><td>married  </td><td>professional.course</td><td>no       </td><td>no       </td><td>no    </td><td>telephone</td><td>may    </td><td>mon          </td><td>139.0             </td><td>1.0               </td><td>999.0             </td><td>0.0                </td><td>nonexistent</td><td>1.1                </td><td>93.994            </td><td>-36.4             </td><td>4.857             </td><td>5191.0            </td><td>no  </td></tr>
# <tr><td>7      </td><td>41.0              </td><td>blue-collar</td><td>married  </td><td>unknown            </td><td>unknown  </td><td>no       </td><td>no    </td><td>telephone</td><td>may    </td><td>mon          </td><td>217.0             </td><td>1.0               </td><td>999.0             </td><td>0.0                </td><td>nonexistent</td><td>1.1                </td><td>93.994            </td><td

# %%
x = bank_df.names
x.remove("y")
print(x)
Y = "y"
# Out:
# ['age', 'job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays', 'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed']

# %%
train, test = bank_df.split_frame([0.7], seed=42)

# %%
from h2o.estimators import H2ORandomForestEstimator

# %%
rf = H2ORandomForestEstimator(ntrees=200)

rf.train(x=x,
         y=Y,
         training_frame=train,
         validation_frame=test)
# Out:
# drf Model Build progress: |███████████████████████████████████████████████| 100%

# %%
print(rf)
# Out:
# Model Details
# =============
# H2ORandomForestEstimator :  Distributed Random Forest
# Model Key:  DRF_model_python_1577963526050_1
#
#
# Model Summary:
#      number_of_trees  ...  max_leaves  mean_leaves
# 0              200.0  ...      2044.0       1829.0
#
# [1 rows x 10 columns]
# ModelMetricsBinomial: drf
# ** Reported on train data. **
#
# MSE: 0.05729102127988641
# RMSE: 0.23935542876627305
# LogLoss: 0.18429657894033188
# Mean Per-Class Error: 0.11249961023184141
# AUC: 0.9419850730621017
# AUCPR: 0.6374774378814864
# Gini: 0.8839701461242033
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.3217825807831748:
#                no     yes   Error               Rate
# 0     no  23665.0  2047.0  0.0796   (2047.0/25712.0)
# 1    yes    725.0  2498.0  0.2249     (725.0/3223.0)
# 2  Total  24390.0  4545.0  0.0958   (2772.0/28935.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold         value    idx
# 0                        max f1   0.321783      0.643151  222.0
# 1                        max f2   0.172540      0.756132  283.0
# 2                  max f0point5   0.491291      0.616336  152.0
# 3                  max accuracy   0.491291      0.914774  152.0
# 4                 max precision   1.000000      1.000000    0.0
# 5                    max recall   0.000038      1.000000  399.0
# 6               max specificity   1.000000      1.000000    0.0
# 7              max absolute_mcc   0.266206      0.603535  244.0
# 8    max min_per_class_accuracy   0.199713      0.879550  271.0
# 9   max mean_per_class_accuracy   0.100069      0.887500  317.0
# 10                      max tns   1.000000  25712.000000    0.0
# 11                      max fns   1.000000   3221.000000    0.0
# 12                      max fps   0.000038  25712.000000  399.0
# 13                      max tps   0.000038   3223.000000  399.0
# 14                      max tnr   1.000000      1.000000    0.0
# 15                      max fnr   1.000000      0.999379    0.0
# 16                      max fpr   0.000038      1.000000  399.0
# 17                      max tpr   0.000038      1.000000  399.0
# Gains/Lift Table: Avg response rate: 11.14 %, avg score: 11.47 %
#       group  ...        gain  cumulative_gain
# 0         1  ...  646.074550       646.074550
# 1         2  ...  533.717216       589.992910
# 2         3  ...  525.340495       568.417306
# 3         4  ...  524.397846       557.431447
# 4         5  ...  456.055793       537.184340
# 5         6  ...  387.660069       462.422205
# 6         7  ...  279.704787       401.516399
# 7         8  ...  144.619520       337.325473
# 8         9  ...   -5.694236       222.972399
# 9        10  ...  -83.242528       146.431896
# 10       11  ...  -94.105890        98.317688
# 11       12  ...  -97.517412        65.684145
# 12       13  ...  -98.448382        42.240114
# 13       14  ...  -98.448918        24.650946
# 14       15  ...  -98.448382        10.975344
# 15       16  ...  -98.759135         0.000000
#
# [16 rows x 14 columns]
# ModelMetricsBinomial: drf
# ** Reported on validation data. **
#
# MSE: 0.05847227384203343
# RMSE: 0.24181040887859528
# LogLoss: 0.18339677943647328
# Mean Per-Class Error: 0.11444463722039999
# AUC: 0.9424618479450995
# AUCPR: 0.6547754102131101
# Gini: 0.8849236958901989
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.29619994391288074:
#                no     yes   Error               Rate
# 0     no   9906.0   930.0  0.0858    (930.0/10836.0)
# 1    yes    298.0  1119.0  0.2103     (298.0/1417.0)
# 2  Total  10204.0  2049.0  0.1002   (1228.0/12253.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold         value    idx
# 0                        max f1   0.296200      0.645701  227.0
# 1                        max f2   0.174944      0.760230  277.0
# 2                  max f0point5   0.553495      0.622287  122.0
# 3                  max accuracy   0.553495      0.912838  122.0
# 4                 max precision   0.973929      1.000000    0.0
# 5                    max recall   0.000364      1.000000  398.0
# 6               max specificity   0.973929      1.000000    0.0
# 7              max absolute_mcc   0.262796      0.604049  240.0
# 8    max min_per_class_accuracy   0.190671      0.878368  270.0
# 9   max mean_per_class_accuracy   0.128989      0.885555  301.0
# 10                      max tns   0.973929  10836.000000    0.0
# 11                      max fns   0.973929   1414.000000    0.0
# 12                      max fps   0.000105  10836.000000  399.0
# 13                      max tps   0.000364   1417.000000  398.0
# 14                      max tnr   0.973929      1.000000    0.0
# 15                      max fnr   0.973929      0.997883    0.0
# 16                      max fpr   0.000105      1.000000  399.0
# 17                      max tpr   0.000364      1.000000  398.0
# Gains/Lift Table: Avg response rate: 11.56 %, avg score: 11.45 %
#       group  ...        gain  cumulative_gain
# 0         1  ...  631.140449       631.140449
# 1         2  ...  595.989466       613.564957
# 2         3  ...  530.816086       586.131908
# 3         4  ...  511.627106       567.467772
# 4         5  ...  459.937874       546.067042
# 5         6  ...  347.168673       446.617858
# 6         7  ...  274.426894       389.283326
# 7         8  ...  159.555318       331.827892
# 8         9  ...    1.648035       221.797879
# 9        10  ...  -78.117437       146.834349
# 10       11  ...  -94.357493        98.572361
# 11       12  ...  -96.470554        66.074052
# 12       13  ...  -98.588222        42.556355
# 13       14  ... -100.000000        24.740447
# 14       15  ...  -99.294111        10.961329
# 15       16  ...  -98.589373         0.000000
#
# [16 rows x 14 columns]
# Scoring History:
#                 timestamp  ... validation_lift  validation_classification_error
# 0     2020-01-02 11:25:42  ...             NaN                              NaN
# 1     2020-01-02 11:25:43  ...        4.554391                         0.116625
# 2     2020-01-02 11:25:43  ...        5.669790                         0.118665
# 3     2020-01-02 11:25:44  ...        6.109150                         0.131968
# 4     2020-01-02 11:25:44  ...        6.476744                         0.106994
# 5     2020-01-02 11:25:45  ...        6.498458                         0.114258
# 6     2020-01-02 11:25:45  ...        6.547122                         0.113197
# 7     2020-01-02 11:25:45  ...        6.538083                         0.118502
# 8     2020-01-02 11:25:46  ...        6.678687                         0.108871
# 9     2020-01-02 11:25:50  ...        7.170801                         0.107239
# 10    2020-01-02 11:25:55  ...        7.241103                         0.098180
# 11    2020-01-02 11:26:02  ...        7.194422                         0.102587
# 12    2020-01-02 11:26:09  ...        7.311404                         0.100220
#
# [13 rows x 16 columns]
# Variable Importances:
#           variable  relative_importance  scaled_importance  percentage
# 0         duration        101413.375000           1.000000    0.283978
# 1        euribor3m         32085.816406           0.316386    0.089847
# 2      nr.employed         25831.003906           0.254710    0.072332
# 3              age         25718.013672           0.253596    0.072016
# 4              job         25436.056641           0.250816    0.071226
# 5      day_of_week         18731.328125           0.184703    0.052452
# 6        education         18579.232422           0.183203    0.052026
# 7            month         14398.808594           0.141981    0.040320
# 8         poutcome         12491.575195           0.123175    0.034979
# 9            pdays         12293.760742           0.121224    0.034425
# 10        campaign         11203.903320           0.110478    0.031373
# 11   cons.conf.idx          9883.229492           0.097455    0.027675
# 12    emp.var.rate          9031.941406           0.089061    0.025291
# 13         marital          8399.850586           0.082828    0.023521
# 14  cons.price.idx          7841.773438           0.077325    0.021959
# 15         housing          6907.895508           0.068116    0.019344
# 16        previous          5374.419922           0.052995    0.015049
# 17            loan          5094.353027           0.050234    0.014265
# 18         contact          3550.213379           0.035007    0.009941
# 19         default          2850.425781           0.028107    0.007982

# %%
predictions = rf.predict(test)
(predictions["predict"] == test["y"]).mean()
# Out:
# drf prediction progress: |████████████████████████████████████████████████| 100%
# [0.8996980331347425]

# %%
from h2o.estimators.deeplearning import H2ODeepLearningEstimator
dl = H2ODeepLearningEstimator(hidden=[100, 10, 4],activation='Tanh')
dl.train(x=x, y=Y, training_frame=train, validation_frame=test)
predictions_dl = dl.predict(test)
print((predictions_dl["predict"] == test["y"]).mean())
# Out:
# deeplearning Model Build progress: |██████████████████████████████████████| 100%
# deeplearning prediction progress: |███████████████████████████████████████| 100%
# [0.891455153839876]

# %%
from h2o.estimators.glm import H2OGeneralizedLinearEstimator
lm = H2OGeneralizedLinearEstimator(family="binomial",
                                   lambda_search=True)

lm.train(x=x,
         y=Y,
         training_frame=train,
         validation_frame=test)
# Out:
# glm Model Build progress: |███████████████████████████████████████████████| 100%

# %%
predictions_lm = lm.predict(test)
print((predictions_lm["predict"] == test["y"]).mean())
# Out:
# glm prediction progress: |████████████████████████████████████████████████| 100%
# [0.9014935117930303]

# %%
from h2o.estimators.gbm import H2OGradientBoostingEstimator
gb = H2OGradientBoostingEstimator()

gb.train(x=x,
         y=Y,
         training_frame=train,
         validation_frame=test)
# Out:
# gbm Model Build progress: |███████████████████████████████████████████████| 100%

# %%
predictions_gb = gb.predict(test)
print((predictions_gb["predict"] == test["y"]).mean())
# Out:
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# [0.9116134824124704]

# %%
from h2o.estimators import H2OXGBoostEstimator

param = {"ntrees" : 400,
         "max_depth" : 4,
         "learn_rate" : 0.01,
         "sample_rate" : 0.4,
         "col_sample_rate_per_tree" : 0.8,
         "min_rows" : 5,
         "seed": 4241,
         "score_tree_interval": 100
         }

xgb = H2OXGBoostEstimator(**param)

xgb.train(x=x,
         y=Y,
         training_frame=train,
         validation_frame=test)

predictions_xgb = xgb.predict(test)
print((predictions_xgb["predict"] == test["y"]).mean())
# Out:
# xgboost Model Build progress: |███████████████████████████████████████████| 100%
# xgboost prediction progress: |████████████████████████████████████████████| 100%
# [0.9059005957724638]

# %%
from h2o.automl import H2OAutoML
autoML = H2OAutoML(max_runtime_secs=120)
autoML.train(x=x,
             y=Y,
             training_frame=bank_df)
# Out:
# AutoML progress: |████████████████████████████████████████████████████████| 100%

# %%
leaderboard = autoML.leaderboard
print(leaderboard)
# Out:
# <table>
# <thead>
# <tr><th>model_id                        </th><th style="text-align: right;">     auc</th><th style="text-align: right;">  logloss</th><th style="text-align: right;">   aucpr</th><th style="text-align: right;">  mean_per_class_error</th><th style="text-align: right;">    rmse</th><th style="text-align: right;">      mse</th></tr>
# </thead>
# <tbody>
# <tr><td>XGBoost_1_AutoML_20200102_120918</td><td style="text-align: right;">0.947234</td><td style="text-align: right;"> 0.186255</td><td style="text-align: right;">0.660012</td><td style="text-align: right;">              0.145329</td><td style="text-align: right;">0.237177</td><td style="text-align: right;">0.0562527</td></tr>
# </tbody>
# </table>

# %%
autoML.leader
# Out:
# Model Details
# =============
# H2OXGBoostEstimator :  XGBoost
# Model Key:  XGBoost_1_AutoML_20200102_120918
#
#
# Model Summary:
#      number_of_trees
# 0               72.0
# ModelMetricsBinomial: xgboost
# ** Reported on train data. **
#
# MSE: 0.04468371289351906
# RMSE: 0.2113852239242825
# LogLoss: 0.1550823017164113
# Mean Per-Class Error: 0.08515882986191048
# AUC: 0.9696288837683462
# AUCPR: 0.8064156535257389
# Gini: 0.9392577675366924
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.4005400286271022:
#                no     yes   Error               Rate
# 0     no  35091.0  1457.0  0.0399   (1457.0/36548.0)
# 1    yes   1133.0  3507.0  0.2442    (1133.0/4640.0)
# 2  Total  36224.0  4964.0  0.0629   (2590.0/41188.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold         value    idx
# 0                        max f1   0.400540      0.730321  183.0
# 1                        max f2   0.193371      0.808713  271.0
# 2                  max f0point5   0.514210      0.754404  136.0
# 3                  max accuracy   0.472604      0.940298  153.0
# 4                 max precision   0.938870      1.000000    0.0
# 5                    max recall   0.017530      1.000000  397.0
# 6               max specificity   0.938870      1.000000    0.0
# 7              max absolute_mcc   0.354312      0.695632  202.0
# 8    max min_per_class_accuracy   0.220980      0.907543  259.0
# 9   max mean_per_class_accuracy   0.155360      0.914841  290.0
# 10                      max tns   0.938870  36548.000000    0.0
# 11                      max fns   0.938870   4633.000000    0.0
# 12                      max fps   0.016499  36548.000000  399.0
# 13                      max tps   0.017530   4640.000000  397.0
# 14                      max tnr   0.938870      1.000000    0.0
# 15                      max fnr   0.938870      0.998491    0.0
# 16                      max fpr   0.016499      1.000000  399.0
# 17                      max tpr   0.017530      1.000000  397.0
# Gains/Lift Table: Avg response rate: 11.27 %, avg score: 12.33 %
#       group  ...        gain  cumulative_gain
# 0         1  ...  779.054235       779.054235
# 1         2  ...  727.345162       753.199699
# 2         3  ...  675.636090       727.345162
# 3         4  ...  641.163375       705.799715
# 4         5  ...  613.154294       687.270631
# 5         6  ...  465.627104       576.475772
# 6         7  ...  238.263517       463.720109
# 7         8  ...   73.309524       366.141158
# 8         9  ...  -43.321718       229.653533
# 9        10  ...  -91.162077       149.464235
# 10       11  ...  -98.491453        99.870690
# 11       12  ...  -99.784493        66.593479
# 12       13  ...  -99.784493        42.824373
# 13       14  ... -100.000000        24.974577
# 14       15  ... -100.000000        11.087764
# 15       16  ...  -99.784493         0.000000
#
# [16 rows x 14 columns]
# ModelMetricsBinomial: xgboost
# ** Reported on cross-validation data. **
#
# MSE: 0.05625274246839676
# RMSE: 0.2371766060731892
# LogLoss: 0.1862545775095024
# Mean Per-Class Error: 0.1078731960426157
# AUC: 0.9472337600198889
# AUCPR: 0.6600119417336202
# Gini: 0.8944675200397778
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.2988580506423424:
#                no     yes   Error               Rate
# 0     no  33723.0  2825.0  0.0773   (2825.0/36548.0)
# 1    yes    990.0  3650.0  0.2134     (990.0/4640.0)
# 2  Total  34713.0  6475.0  0.0926   (3815.0/41188.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold         value    idx
# 0                        max f1   0.298858      0.656770  218.0
# 1                        max f2   0.156934      0.763929  280.0
# 2                  max f0point5   0.495321      0.630250  140.0
# 3                  max accuracy   0.495321      0.916505  140.0
# 4                 max precision   0.955237      1.000000    0.0
# 5                    max recall   0.002674      1.000000  399.0
# 6               max specificity   0.955237      1.000000    0.0
# 7              max absolute_mcc   0.281021      0.616709  226.0
# 8    max min_per_class_accuracy   0.189383      0.883003  264.0
# 9   max mean_per_class_accuracy   0.121155      0.892127  300.0
# 10                      max tns   0.955237  36548.000000    0.0
# 11                      max fns   0.955237   4638.000000    0.0
# 12                      max fps   0.002674  36548.000000  399.0
# 13                      max tps   0.002674   4640.000000  399.0
# 14                      max tnr   0.955237      1.000000    0.0
# 15                      max fnr   0.955237      0.999569    0.0
# 16                      max fpr   0.002674      1.000000  399.0
# 17                      max tpr   0.002674      1.000000  399.0
# Gains/Lift Table: Avg response rate: 11.27 %, avg score: 12.69 %
#       group  ...        gain  cumulative_gain
# 0         1  ...  660.554277       660.554277
# 1         2  ...  578.681579       619.617928
# 2         3  ...  509.736148       582.990668
# 3         4  ...  505.427059       563.599766
# 4         5  ...  501.117970       551.103406
# 5         6  ...  389.750297       470.446438
# 6         7  ...  285.232591       408.698498
# 7         8  ...  130.648247       339.202811
# 8         9  ...   -1.944417       225.487069
# 9        10  ...  -84.264185       148.063356
# 10       11  ...  -97.413919        98.965517
# 11       12  ...  -98.708527        65.985189
# 12       13  ...  -99.784179        42.336706
# 13       14  ...  -99.353480        24.624358
# 14       15  ...  -97.198412        11.087764
# 15       16  ...  -99.784493         0.000000
#
# [16 rows x 14 columns]
# Cross-Validation Metrics Summary:
#                                     mean  ...   cv_4_valid  cv_5_valid
# 0                  accuracy    0.9076916  ...    0.9161102  0.90105623
# 1                       auc    0.9490813  ...    0.9503061  0.94716686
# 2                     aucpr    0.6604034  ...    0.6800325    0.650207
# 3                       err  0.092308395  ...   0.08388977  0.09894379
# 4                 err_count        760.4  ...        691.0       815.0
# 5                  f0point5    0.5995119  ...    0.6299567   0.5805038
# 6                        f1    0.6591056  ...   0.66921973  0.64549804
# 7                        f2   0.73247653  ...   0.71370226  0.72688085
# 8            lift_top_group    7.5937004  ...      7.63392   7.3236647
# 9                   logloss   0.18625443  ...   0.18784794   0.1783701
# 10      max_per_class_error    0.2083102  ...   0.25320512  0.20641711
# 11                      mcc   0.61946106  ...    0.6262092  0.60454047
# 12  mean_per_class_accuracy    0.8570621  ...    0.8423058  0.85420036
# 13     mean_per_class_error   0.14293791  ...   0.15769419  0.14579962
# 14                      mse   0.05625275  ...  0.055526365   0.0572826
# 15                   pr_auc    0.6604034  ...    0.6800325    0.650207
# 16                precision    0.5655987  ...   0.60624456   0.5439883
# 17                       r2   0.43721515  ...    0.4487112  0.43074426
# 18                   recall    0.7916898  ...    0.7467949   0.7935829
# 19                     rmse    0.2371726  ...   0.23564033  0.23933783
#
# [20 rows x 8 columns]
# See the whole table with table.as_data_frame()
#
# Scoring History:
#                 timestamp  ... training_lift  training_classification_error
# 0     2020-01-02 12:10:54  ...      1.000000                       0.887346
# 1     2020-01-02 12:10:55  ...      8.107547                       0.080970
# 2     2020-01-02 12:10:56  ...      8.187270                       0.079319
# 3     2020-01-02 12:10:57  ...      8.359633                       0.075823
# 4     2020-01-02 12:10:58  ...      8.531997                       0.074706
# 5     2020-01-02 12:10:59  ...      8.661270                       0.075750
# 6     2020-01-02 12:11:00  ...      8.704361                       0.072327
# 7     2020-01-02 12:11:01  ...      8.725906                       0.075410
# 8     2020-01-02 12:11:03  ...      8.725906                       0.072181
# 9     2020-01-02 12:11:04  ...      8.682815                       0.072181
# 10    2020-01-02 12:11:05  ...      8.704361                       0.070652
# 11    2020-01-02 12:11:06  ...      8.747451                       0.069583
# 12    2020-01-02 12:11:08  ...      8.747451                       0.069292
# 13    2020-01-02 12:11:09  ...      8.747451                       0.063489
# 14    2020-01-02 12:11:10  ...      8.768997                       0.062737
# 15    2020-01-02 12:11:10  ...      8.790542                       0.062882
#
# [16 rows x 10 columns]
# Variable Importances:
#                        variable  ...  percentage
# 0                      duration  ...    0.420421
# 1                   nr.employed  ...    0.184824
# 2                     euribor3m  ...    0.115494
# 3                           age  ...    0.036612
# 4                 cons.conf.idx  ...    0.032612
# 5                  emp.var.rate  ...    0.026398
# 6                         pdays  ...    0.023291
# 7                cons.price.idx  ...    0.020032
# 8                      campaign  ...    0.013598
# 9              poutcome.success  ...    0.011821
# 10                    month.oct  ...    0.009482
# 11                    month.may  ...    0.006940
# 12  education.university.degree  ...    0.006125
# 13             contact.cellular  ...    0.005875
# 14              day_of_week.thu  ...    0.005610
# 15             poutcome.failure  ...    0.005603
# 16              day_of_week.mon  ...    0.004829
# 17                   housing.no  ...    0.003821
# 18               marital.single  ...    0.003644
# 19              day_of_week.tue  ...    0.003613
#
# [20 rows x 4 columns]
# See the whole table with table.as_data_frame()
