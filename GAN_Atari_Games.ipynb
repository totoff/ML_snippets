# %%
# !rm -rf *

# %%
pip install tensorboard-pytorch
# Out:
# Requirement already satisfied: tensorboard-pytorch in /usr/local/lib/python3.6/dist-packages (0.7.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.6/dist-packages (from tensorboard-pytorch) (3.7.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from tensorboard-pytorch) (1.12.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from tensorboard-pytorch) (1.16.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf->tensorboard-pytorch) (41.0.1)

# %%
import random
import argparse
import cv2

import torch
import torch.nn as nn
import torch.optim as optim
from tensorboardX import SummaryWriter

import torchvision.utils as vutils

import gym
import gym.spaces

import numpy as np

log = gym.logger
log.set_level(gym.logger.INFO)

LATENT_VECTOR_SIZE = 100
DISCR_FILTERS = 64
GENER_FILTERS = 64
BATCH_SIZE = 16

# dimension input image will be rescaled
IMAGE_SIZE = 64

LEARNING_RATE = 0.0001
REPORT_EVERY_ITER = 100
SAVE_IMAGE_EVERY_ITER = 1000

# %%
class InputWrapper(gym.ObservationWrapper):
    """
    Preprocessing of input numpy array:
    1. resize image into predefined size
    2. move color channel axis to a first place
    """
    def __init__(self, *args):
        super(InputWrapper, self).__init__(*args)
        assert isinstance(self.observation_space, gym.spaces.Box)
        old_space = self.observation_space
        self.observation_space = gym.spaces.Box(self.observation(old_space.low), self.observation(old_space.high),
                                                dtype=np.float32)

    def observation(self, observation):
        # resize image
        new_obs = cv2.resize(observation, (IMAGE_SIZE, IMAGE_SIZE))
        # transform (210, 160, 3) -> (3, 210, 160)
        new_obs = np.moveaxis(new_obs, 2, 0)
        return new_obs.astype(np.float32)

# %%
class Discriminator(nn.Module):
    def __init__(self, input_shape):
        super(Discriminator, self).__init__()
        # this pipe converges image into the single number
        self.conv_pipe = nn.Sequential(
            nn.Conv2d(in_channels=input_shape[0], out_channels=DISCR_FILTERS,
                      kernel_size=4, stride=2, padding=1),
            nn.ReLU(),
            nn.Conv2d(in_channels=DISCR_FILTERS, out_channels=DISCR_FILTERS*2,
                      kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(DISCR_FILTERS*2),
            nn.ReLU(),
            nn.Conv2d(in_channels=DISCR_FILTERS * 2, out_channels=DISCR_FILTERS * 4,
                      kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(DISCR_FILTERS * 4),
            nn.ReLU(),
            nn.Conv2d(in_channels=DISCR_FILTERS * 4, out_channels=DISCR_FILTERS * 8,
                      kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(DISCR_FILTERS * 8),
            nn.ReLU(),
            nn.Conv2d(in_channels=DISCR_FILTERS * 8, out_channels=1,
                      kernel_size=4, stride=1, padding=0),
            nn.Sigmoid()
        )

    def forward(self, x):
        conv_out = self.conv_pipe(x)
        return conv_out.view(-1, 1).squeeze(dim=1)

# %%
class Generator(nn.Module):
    def __init__(self, output_shape):
        super(Generator, self).__init__()
        # pipe deconvolves input vector into (3, 64, 64) image
        self.pipe = nn.Sequential(
            nn.ConvTranspose2d(in_channels=LATENT_VECTOR_SIZE, out_channels=GENER_FILTERS * 8,
                               kernel_size=4, stride=1, padding=0),
            nn.BatchNorm2d(GENER_FILTERS * 8),
            nn.ReLU(),
            nn.ConvTranspose2d(in_channels=GENER_FILTERS * 8, out_channels=GENER_FILTERS * 4,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(GENER_FILTERS * 4),
            nn.ReLU(),
            nn.ConvTranspose2d(in_channels=GENER_FILTERS * 4, out_channels=GENER_FILTERS * 2,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(GENER_FILTERS * 2),
            nn.ReLU(),
            nn.ConvTranspose2d(in_channels=GENER_FILTERS * 2, out_channels=GENER_FILTERS,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(GENER_FILTERS),
            nn.ReLU(),
            nn.ConvTranspose2d(in_channels=GENER_FILTERS, out_channels=output_shape[0],
                               kernel_size=4, stride=2, padding=1),
            nn.Tanh()
        )

    def forward(self, x):
        return self.pipe(x)

# %%
def iterate_batches(envs, batch_size=BATCH_SIZE):
    batch = [e.reset() for e in envs]
    env_gen = iter(lambda: random.choice(envs), None)

    while True:
        e = next(env_gen)
        obs, reward, is_done, _ = e.step(e.action_space.sample())
        if np.mean(obs) > 0.01:
            batch.append(obs)
        if len(batch) == batch_size:
            # Normalising input between -1 to 1
            batch_np = np.array(batch, dtype=np.float32) * 2.0 / 255.0 - 1.0
            yield torch.tensor(batch_np)
            batch.clear()
        if is_done:
            e.reset()

# %%
device = torch.device("cuda")
envs = [InputWrapper(gym.make(name)) for name in ('Breakout-v0', 'AirRaid-v0', 'Pong-v0')]
input_shape = envs[0].observation_space.shape

net_discr = Discriminator(input_shape=input_shape).to(device)
net_gener = Generator(output_shape=input_shape).to(device)

objective = nn.BCELoss()
gen_optimizer = optim.Adam(params=net_gener.parameters(), lr=LEARNING_RATE, betas=(0.5, 0.999))
dis_optimizer = optim.Adam(params=net_discr.parameters(), lr=LEARNING_RATE, betas=(0.5, 0.999))
writer = SummaryWriter()

gen_losses = []
dis_losses = []
iter_no = 0

true_labels_v = torch.ones(BATCH_SIZE, dtype=torch.float32, device=device)
fake_labels_v = torch.zeros(BATCH_SIZE, dtype=torch.float32, device=device)

for batch_v in iterate_batches(envs):
  # generate extra fake samples, input is 4D: batch, filters, x, y
  gen_input_v = torch.FloatTensor(BATCH_SIZE, LATENT_VECTOR_SIZE, 1, 1).normal_(0, 1).to(device)
  batch_v = batch_v.to(device)
  
  = net_gener(gen_input_v)
  
  # train discriminator
  dis_optimizer.zero_grad()
  dis_output_true_v = net_discr(batch_v)
  dis_output_fake_v = net_discr(gen_output_v.detach())
  dis_loss = objective(dis_output_true_v, true_labels_v) + objective(dis_output_fake_v, fake_labels_v)
  dis_loss.backward()
  dis_optimizer.step()
  dis_losses.append(dis_loss.item())

  # train generator
  gen_optimizer.zero_grad()
  dis_output_v = net_discr(gen_output_v)
  gen_loss_v = objective(dis_output_v, true_labels_v)
  gen_loss_v.backward()
  gen_optimizer.step()
  gen_losses.append(gen_loss_v.item())

  iter_no += 1
  if iter_no % REPORT_EVERY_ITER == 0:
    log.info("Iter %d: gen_loss=%.3e, dis_loss=%.3e", iter_no, np.mean(gen_losses), np.mean(dis_losses))
    writer.add_scalar("gen_loss", np.mean(gen_losses), iter_no)
    writer.add_scalar("dis_loss", np.mean(dis_losses), iter_no)
    gen_losses = []
    dis_losses = []
  if iter_no % SAVE_IMAGE_EVERY_ITER == 0:
    writer.add_image("fake", vutils.make_grid(gen_output_v.data[:64], normalize=True), iter_no)
    writer.add_image("real", vutils.make_grid(batch_v.data[:64], normalize=True), iter_no)
# Out:
# INFO: Making new env: Breakout-v0
# INFO: Making new env: AirRaid-v0
# INFO: Making new env: Pong-v0
# INFO: Iter 100: gen_loss=4.336e+00, dis_loss=9.282e-02
# INFO: Iter 200: gen_loss=6.152e+00, dis_loss=8.855e-03
# INFO: Iter 300: gen_loss=6.764e+00, dis_loss=3.471e-03
# INFO: Iter 400: gen_loss=7.121e+00, dis_loss=2.837e-03
# INFO: Iter 500: gen_loss=7.731e+00, dis_loss=1.233e-03
# INFO: Iter 600: gen_loss=5.918e+00, dis_loss=2.326e-01
# INFO: Iter 700: gen_loss=6.397e+00, dis_loss=8.799e-03
# INFO: Iter 800: gen_loss=6.536e+00, dis_loss=3.282e-03
# INFO: Iter 900: gen_loss=7.073e+00, dis_loss=6.067e-02
# INFO: Iter 1000: gen_loss=6.416e+00, dis_loss=1.423e-02
# INFO: Iter 1100: gen_loss=8.365e+00, dis_loss=3.374e-02
# INFO: Iter 1200: gen_loss=5.538e+00, dis_loss=1.087e-01
# INFO: Iter 1300: gen_loss=5.788e+00, dis_loss=9.230e-03
# INFO: Iter 1400: gen_loss=6.373e+00, dis_loss=3.073e-02
# INFO: Iter 1500: gen_loss=6.396e+00, dis_loss=1.055e-01
# INFO: Iter 1600: gen_loss=5.114e+00, dis_loss=2.308e-01
# INFO: Iter 1700: gen_loss=4.030e+00, dis_loss=3.497e-01
# INFO: Iter 1800: gen_loss=4.225e+00, dis_loss=2.826e-01
# INFO: Iter 1900: gen_loss=4.655e+00, dis_loss=2.741e-01
# INFO: Iter 2000: gen_loss=4.998e+00, dis_loss=1.727e-01
# INFO: Iter 2100: gen_loss=4.270e+00, dis_loss=2.483e-01
# INFO: Iter 2200: gen_loss=3.921e+00, dis_loss=2.615e-01
# INFO: Iter 2300: gen_loss=4.523e+00, dis_loss=2.370e-01
# INFO: Iter 2400: gen_loss=4.683e+00, dis_loss=1.413e-01
# INFO: Iter 2500: gen_loss=5.438e+00, dis_loss=7.838e-02
# INFO: Iter 2600: gen_loss=5.254e+00, dis_loss=1.890e-01
# INFO: Iter 2700: gen_loss=3.807e+00, dis_loss=3.343e-01
# INFO: Iter 2800: gen_loss=5.081e+00, dis_loss=1.261e-01
# INFO: Iter 2900: gen_loss=5.181e+00, dis_loss=1.004e-01
# INFO: Iter 3000: gen_loss=5.307e+00, dis_loss=1.360e-01
# INFO: Iter 3100: gen_loss=4.476e+00, dis_loss=1.774e-01
# INFO: Iter 3200: gen_loss=4.554e+00, dis_loss=1.839e-01
# INFO: Iter 3300: gen_loss=4.319e+00, dis_loss=1.996e-01
# INFO: Iter 3400: gen_loss=4.430e+00, dis_loss=1.960e-01
# INFO: Iter 3500: gen_loss=4.992e+00, dis_loss=1.637e-01
# INFO: Iter 3600: gen_loss=5.253e+00, dis_loss=1.113e-01
# INFO: Iter 3700: gen_loss=5.436e+00, dis_loss=1.675e-01
# INFO: Iter 3800: gen_loss=5.476e+00, dis_loss=3.517e-02
# INFO: Iter 3900: gen_loss=5.135e+00, dis_loss=2.675e-01
# INFO: Iter 4000: gen_loss=5.032e+00, dis_loss=1.745e-01
# INFO: Iter 4100: gen_loss=4.899e+00, dis_loss=1.974e-01
# INFO: Iter 4200: gen_loss=5.590e+00, dis_loss=1.515e-01
# INFO: Iter 4300: gen_loss=4.715e+00, dis_loss=1.256e-01
# INFO: Iter 4400: gen_loss=5.264e+00, dis_loss=9.488e-02
# INFO: Iter 4500: gen_loss=5.260e+00, dis_loss=2.618e-01
# INFO: Iter 4600: gen_loss=5.319e+00, dis_loss=6.167e-02
# INFO: Iter 4700: gen_loss=6.225e+00, dis_loss=9.960e-03
# INFO: Iter 4800: gen_loss=5.448e+00, dis_loss=1.608e-01
# INFO: Iter 4900: gen_loss=5.675e+00, dis_loss=1.966e-01
# INFO: Iter 5000: gen_loss=4.641e+00, dis_loss=2.106e-01
# INFO: Iter 5100: gen_loss=5.329e+00, dis_loss=1.682e-01
# INFO: Iter 5200: gen_loss=4.402e+00, dis_loss=2.769e-01
# INFO: Iter 5300: gen_loss=5.048e+00, dis_loss=1.885e-01
# INFO: Iter 5400: gen_loss=5.677e+00, dis_loss=6.126e-02
# INFO: Iter 5500: gen_loss=5.299e+00, dis_loss=2.956e-01
# INFO: Iter 5600: gen_loss=4.857e+00, dis_loss=2.084e-01
# INFO: Iter 5700: gen_loss=5.526e+00, dis_loss=8.853e-02
# INFO: Iter 5800: gen_loss=5.141e+00, dis_loss=1.288e-01
# INFO: Iter 5900: gen_loss=4.893e+00, dis_loss=1.540e-01
# INFO: Iter 6000: gen_loss=4.028e+00, dis_loss=2.834e-01
# INFO: Iter 6100: gen_loss=4.634e+00, dis_loss=1.700e-01
# INFO: Iter 6200: gen_loss=4.575e+00, dis_loss=1.852e-01
# INFO: Iter 6300: gen_loss=4.494e+00, dis_loss=1.495e-01
# INFO: Iter 6400: gen_loss=4.888e+00, dis_loss=7.431e-02
# INFO: Iter 6500: gen_loss=5.319e+00, dis_loss=1.952e-01
# INFO: Iter 6600: gen_loss=5.162e+00, dis_loss=1.922e-01
# INFO: Iter 6700: gen_loss=5.391e+00, dis_loss=5.847e-02
# INFO: Iter 6800: gen_loss=5.508e+00, dis_loss=1.633e-01
# INFO: Iter 6900: gen_loss=5.149e+00, dis_loss=2.148e-01
# INFO: Iter 7000: gen_loss=4.757e+00, dis_loss=1.501e-01
# INFO: Iter 7100: gen_loss=5.161e+00, dis_loss=9.812e-02
# INFO: Iter 7200: gen_loss=6.509e+00, dis_loss=1.505e-02
# INFO: Iter 7300: gen_loss=5.910e+00, dis_loss=6.626e-02
# INFO: Iter 7400: gen_loss=5.841e+00, dis_loss=8.159e-03
# INFO: Iter 7500: gen_loss=6.834e+00, dis_loss=7.000e-03
# INFO: Iter 7600: gen_loss=6.032e+00, dis_loss=2.229e-01
# INFO: Iter 7700: gen_loss=5.012e+00, dis_loss=1.578e-01
# INFO: Iter 7800: gen_loss=6.044e+00, dis_loss=1.933e-02
# INFO: Iter 7900: gen_loss=5.900e+00, dis_loss=1.593e-01
# INFO: Iter 8000: gen_loss=5.199e+00, dis_loss=1.766e-01
# INFO: Iter 8100: gen_loss=5.662e+00, dis_loss=1.037e-01
# INFO: Iter 8200: gen_loss=6.443e+00, dis_loss=1.175e-01
# INFO: Iter 8300: gen_loss=4.482e+00, dis_loss=2.387e-01
# INFO: Iter 8400: gen_loss=5.545e+00, dis_loss=1.156e-01
# INFO: Iter 8500: gen_loss=6.380e+00, dis_loss=7.574e-02
# INFO: Iter 8600: gen_loss=5.772e+00, dis_loss=2.902e-01
# INFO: Iter 8700: gen_loss=4.668e+00, dis_loss=2.185e-01
# INFO: Iter 8800: gen_loss=5.397e+00, dis_loss=1.035e-01
# INFO: Iter 8900: gen_loss=5.881e+00, dis_loss=6.113e-02
# INFO: Iter 9000: gen_loss=5.728e+00, dis_loss=1.997e-01
# INFO: Iter 9100: gen_loss=5.231e+00, dis_loss=3.796e-02
# INFO: Iter 9200: gen_loss=5.930e+00, dis_loss=1.012e-02
# INFO: Iter 9300: gen_loss=6.832e+00, dis_loss=7.573e-03
# INFO: Iter 9400: gen_loss=7.064e+00, dis_loss=7.319e-03
# INFO: Iter 9500: gen_loss=7.019e+00, dis_loss=8.285e-02
# INFO: Iter 9600: gen_loss=5.465e+00, dis_loss=2.321e-01
# INFO: Iter 9700: gen_loss=5.666e+00, dis_loss=1.225e-01
# INFO: Iter 9800: gen_loss=5.971e+00, dis_loss=1.289e-01
# INFO: Iter 9900: gen_loss=6.073e+00, dis_loss=1.279e-01
# INFO: Iter 10000: gen_loss=5.996e+00, dis_loss=8.525e-02
# INFO: Iter 10100: gen_loss=6.038e+00, dis_loss=1.445e-01
# INFO: Iter 10200: gen_loss=5.415e+00, dis_loss=1.736e-01
# INFO: Iter 10300: gen_loss=6.357e+00, dis_loss=2.414e-02
# INFO: Iter 10400: gen_loss=6.305e+00, dis_loss=3.390e-02
# INFO: Iter 10500: gen_loss=5.713e+00, dis_loss=2.021e-01
# INFO: Iter 10600: gen_loss=5.441e+00, dis_loss=1.559e-01
# INFO: Iter 10700: gen_loss=5.763e+00, dis_loss=1.255e-01
# INFO: Iter 10800: gen_loss=5.294e+00, dis_loss=1.966e-01
# INFO: Iter 10900: gen_loss=6.357e+00, dis_loss=1.327e-02
# INFO: Iter 11000: gen_loss=6.041e+00, dis_loss=2.147e-01
# INFO: Iter 11100: gen_loss=5.561e+00, dis_loss=1.223e-01
# INFO: Iter 11200: gen_loss=4.762e+00, dis_loss=2.380e-01
# INFO: Iter 11300: gen_loss=5.209e+00, dis_loss=3.435e-02
# INFO: Iter 11400: gen_loss=5.139e+00, dis_loss=2.317e-02
# INFO: Iter 11500: gen_loss=5.497e+00, dis_loss=1.062e-01
# INFO: Iter 11600: gen_loss=5.797e+00, dis_loss=5.209e-02
# INFO: Iter 11700: gen_loss=6.159e+00, dis_loss=2.604e-02
# INFO: Iter 11800: gen_loss=6.697e+00, dis_loss=1.790e-02
# INFO: Iter 11900: gen_loss=7.066e+00, dis_loss=4.787e-02
# INFO: Iter 12000: gen_loss=5.753e+00, dis_loss=8.888e-02
# INFO: Iter 12100: gen_loss=6.150e+00, dis_loss=1.952e-01
# INFO: Iter 12200: gen_loss=6.044e+00, dis_loss=3.110e-02
# INFO: Iter 12300: gen_loss=6.681e+00, dis_loss=3.539e-02
# INFO: Iter 12400: gen_loss=6.124e+00, dis_loss=1.475e-01
# INFO: Iter 12500: gen_loss=6.294e+00, dis_loss=2.231e-01
# INFO: Iter 12600: gen_loss=5.658e+00, dis_loss=5.041e-02
# INFO: Iter 12700: gen_loss=5.869e+00, dis_loss=8.028e-02
# INFO: Iter 12800: gen_loss=6.636e+00, dis_loss=1.325e-02
# INFO: Iter 12900: gen_loss=6.652e+00, dis_loss=3.784e-02
# INFO: Iter 13000: gen_loss=6.494e+00, dis_loss=4.600e-02
# INFO: Iter 13100: gen_loss=7.550e+00, dis_loss=3.439e-02
# INFO: Iter 13200: gen_loss=7.764e+00, dis_loss=4.159e-03
# INFO: Iter 13300: gen_loss=7.084e+00, dis_loss=3.265e-03
# INFO: Iter 13400: gen_loss=7.130e+00, dis_loss=3.565e-03
# INFO: Iter 13500: gen_loss=7.336e+00, dis_loss=2.991e-03
# INFO: Iter 13600: gen_loss=7.654e+00, dis_loss=4.854e-03
# INFO: Iter 13700: gen_loss=7.818e+00, dis_loss=2.555e-02
# INFO: Iter 13800: gen_loss=6.159e+00, dis_loss=2.900e-01
# INFO: Iter 13900: gen_loss=6.042e+00, dis_loss=8.708e-02
# INFO: Iter 14000: gen_loss=5.733e+00, dis_loss=1.276e-01
# INFO: Iter 14100: gen_loss=6.620e+00, dis_loss=8.866e-03
# INFO: Iter 14200: gen_loss=7.258e+00, dis_loss=9.982e-03
# INFO: Iter 14300: gen_loss=5.942e+00, dis_loss=1.135e-01
# INFO: Iter 14400: gen_loss=6.824e+00, dis_loss=9.464e-03
# INFO: Iter 14500: gen_loss=7.435e+00, dis_loss=6.472e-03
# INFO: Iter 14600: gen_loss=7.628e+00, dis_loss=3.920e-03
# INFO: Iter 14700: gen_loss=7.241e+00, dis_loss=3.100e-03
# INFO: Iter 14800: gen_loss=7.604e+00, dis_loss=2.131e-03
# INFO: Iter 14900: gen_loss=6.902e+00, dis_loss=3.866e-03
# INFO: Iter 15000: gen_loss=6.937e+00, dis_loss=2.792e-03
# INFO: Iter 15100: gen_loss=6.922e+00, dis_loss=2.466e-03
# INFO: Iter 15200: gen_loss=7.227e+00, dis_loss=2.331e-03
# INFO: Iter 15300: gen_loss=7.396e+00, dis_loss=2.870e-03
# INFO: Iter 15400: gen_loss=7.850e+00, dis_loss=2.238e-03
# INFO: Iter 15500: gen_loss=8.119e+00, dis_loss=1.285e-03
# INFO: Iter 15600: gen_loss=8.244e+00, dis_loss=1.208e-03
# INFO: Iter 15700: gen_loss=8.360e+00, dis_loss=9.404e-04
# INFO: Iter 15800: gen_loss=8.392e+00, dis_loss=1.565e-03
# INFO: Iter 15900: gen_loss=8.525e+00, dis_loss=1.811e-01
# INFO: Iter 16000: gen_loss=5.503e+00, dis_loss=1.782e-01
# INFO: Iter 16100: gen_loss=5.409e+00, dis_loss=2.292e-01
# INFO: Iter 16200: gen_loss=6.503e+00, dis_loss=2.899e-02
# INFO: Iter 16300: gen_loss=7.936e+00, dis_loss=1.118e-02
# INFO: Iter 16400: gen_loss=7.036e+00, dis_loss=3.369e-01
# INFO: Iter 16500: gen_loss=5.902e+00, dis_loss=1.885e-02
# INFO: Iter 16600: gen_loss=5.561e+00, dis_loss=2.157e-01
# INFO: Iter 16700: gen_loss=5.957e+00, dis_loss=7.734e-02
# INFO: Iter 16800: gen_loss=6.722e+00, dis_loss=7.336e-03
# INFO: Iter 16900: gen_loss=6.550e+00, dis_loss=8.310e-02
# INFO: Iter 17000: gen_loss=6.351e+00, dis_loss=4.128e-02
# INFO: Iter 17100: gen_loss=6.434e+00, dis_loss=2.331e-01
# INFO: Iter 17200: gen_loss=5.591e+00, dis_loss=1.106e-01
# INFO: Iter 17300: gen_loss=5.977e+00, dis_loss=1.000e-01
# INFO: Iter 17400: gen_loss=6.728e+00, dis_loss=1.568e-02
# INFO: Iter 17500: gen_loss=6.884e+00, dis_loss=3.155e-02
# INFO: Iter 17600: gen_loss=7.802e+00, dis_loss=3.124e-02
# INFO: Iter 17700: gen_loss=6.834e+00, dis_loss=2.073e-01
# INFO: Iter 17800: gen_loss=6.262e+00, dis_loss=1.226e-02
# INFO: Iter 17900: gen_loss=6.351e+00, dis_loss=5.282e-03
# INFO: Iter 18000: gen_loss=6.640e+00, dis_loss=3.285e-03
# INFO: Iter 18100: gen_loss=6.590e+00, dis_loss=3.419e-03
# INFO: Iter 18200: gen_loss=6.369e+00, dis_loss=4.242e-03
# INFO: Iter 18300: gen_loss=6.851e+00, dis_loss=3.078e-03
# INFO: Iter 18400: gen_loss=5.564e+00, dis_loss=5.289e-01
# INFO: Iter 18500: gen_loss=5.534e+00, dis_loss=1.697e-01
# INFO: Iter 18600: gen_loss=5.894e+00, dis_loss=1.327e-01
# INFO: Iter 18700: gen_loss=5.730e+00, dis_loss=1.727e-01
# INFO: Iter 18800: gen_loss=5.797e+00, dis_loss=1.684e-01
# INFO: Iter 18900: gen_loss=6.736e+00, dis_loss=4.444e-02
# INFO: Iter 19000: gen_loss=5.480e+00, dis_loss=1.604e-01
# INFO: Iter 19100: gen_loss=4.912e+00, dis_loss=2.638e-01
# INFO: Iter 19200: gen_loss=5.756e+00, dis_loss=1.646e-01
# INFO: Iter 19300: gen_loss=6.069e+00, dis_loss=9.627e-02
# INFO: Iter 19400: gen_loss=6.111e+00, dis_loss=2.743e-01
# INFO: Iter 19500: gen_loss=5.826e+00, dis_loss=8.508e-02
# INFO: Iter 19600: gen_loss=5.715e+00, dis_loss=1.187e-01
# INFO: Iter 19700: gen_loss=5.857e+00, dis_loss=1.576e-01
# INFO: Iter 19800: gen_loss=5.961e+00, dis_loss=1.475e-01
# INFO: Iter 19900: gen_loss=6.092e+00, dis_loss=1.733e-01
# INFO: Iter 20000: gen_loss=5.749e+00, dis_loss=1.694e-01
# INFO: Iter 20100: gen_loss=5.586e+00, dis_loss=1.314e-01
# INFO: Iter 20200: gen_loss=5.828e+00, dis_loss=7.807e-02
# INFO: Iter 20300: gen_loss=6.982e+00, dis_loss=1.705e-02
# INFO: Iter 20400: gen_loss=7.594e+00, dis_loss=8.760e-02
# INFO: Iter 20500: gen_loss=6.605e+00, dis_loss=3.327e-02
# INFO: Iter 20600: gen_loss=6.302e+00, dis_loss=1.190e-01
# INFO: Iter 20700: gen_loss=5.672e+00, dis_loss=1.379e-01
# INFO: Iter 20800: gen_loss=5.985e+00, dis_loss=3.137e-02
# INFO: Iter 20900: gen_loss=5.814e+00, dis_loss=6.606e-03
# INFO: Iter 21000: gen_loss=5.884e+00, dis_loss=8.377e-03
# INFO: Iter 21100: gen_loss=6.128e+00, dis_loss=3.749e-03
# INFO: Iter 21200: gen_loss=6.476e+00, dis_loss=2.544e-03
# INFO: Iter 21300: gen_loss=6.415e+00, dis_loss=3.583e-03
# INFO: Iter 21400: gen_loss=6.639e+00, dis_loss=3.728e-03
# INFO: Iter 21500: gen_loss=6.431e+00, dis_loss=4.083e-03
# INFO: Iter 21600: gen_loss=6.306e+00, dis_loss=6.133e-03
# INFO: Iter 21700: gen_loss=7.306e+00, dis_loss=2.804e-03
# INFO: Iter 21800: gen_loss=7.673e+00, dis_loss=1.542e-03
# INFO: Iter 21900: gen_loss=8.023e+00, dis_loss=1.175e-03
# INFO: Iter 22000: gen_loss=8.083e+00, dis_loss=1.514e-03
# INFO: Iter 22100: gen_loss=8.641e+00, dis_loss=8.564e-04
# INFO: Iter 22200: gen_loss=8.795e+00, dis_loss=7.046e-04
# INFO: Iter 22300: gen_loss=8.508e+00, dis_loss=7.777e-04
# INFO: Iter 22400: gen_loss=8.855e+00, dis_loss=6.855e-04
# INFO: Iter 22500: gen_loss=7.871e+00, dis_loss=1.945e-01
# INFO: Iter 22600: gen_loss=5.664e+00, dis_loss=2.051e-02
# INFO: Iter 22700: gen_loss=6.147e+00, dis_loss=6.722e-03
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-a20527af66b2> in <module>()
#      18 fake_labels_v = torch.zeros(BATCH_SIZE, dtype=torch.float32, device=device)
#      19
# ---> 20 for batch_v in iterate_batches(envs):
#      21   # generate extra fake samples, input is 4D: batch, filters, x, y
#      22   gen_input_v = torch.FloatTensor(BATCH_SIZE, LATENT_VECTOR_SIZE, 1, 1).normal_(0, 1).to(device)
#
# <ipython-input-10-c84040efed80> in iterate_batches(envs, batch_size)
#       5     while True:
#       6         e = next(env_gen)
# ----> 7         obs, reward, is_done, _ = e.step(e.action_space.sample())
#       8         if np.mean(obs) > 0.01:
#       9             batch.append(obs)
#
# /usr/local/lib/python3.6/dist-packages/gym/core.py in step(self, action)
#     303 class ObservationWrapper(Wrapper):
#     304     def step(self, action):
# --> 305         observation, reward, done, info = self.env.step(action)
#     306         return self.observation(observation), reward, done, info
#     307
#
# /usr/local/lib/python3.6/dist-packages/gym/wrappers/time_limit.py in step(self, action)
#      29     def step(self, action):
#      30         assert self._episode_started_at is not None, "Cannot call env.step() before calling reset()"
# ---> 31         observation, reward, done, info = self.env.step(action)
#      32         self._elapsed_steps += 1
#      33
#
# /usr/local/lib/python3.6/dist-packages/gym/envs/atari/atari_env.py in step(self, a)
#      75             num_steps = self.np_random.randint(self.frameskip[0], self.frameskip[1])
#      76         for _ in range(num_steps):
# ---> 77             reward += self.ale.act(action)
#      78         ob = self._get_obs()
#      79
#
# /usr/local/lib/python3.6/dist-packages/atari_py/ale_python_interface.py in act(self, action)
#     138
#     139     def act(self, action):
# --> 140         return ale_lib.act(self.obj, int(action))
#     141
#     142     def game_over(self):
#
# KeyboardInterrupt:

# %%
writer.close()

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Out:
# --2019-06-08 11:52:53--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 3.92.108.98, 52.71.139.107, 52.22.236.254, ...
# Connecting to bin.equinox.io (bin.equinox.io)|3.92.108.98|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16648024 (16M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  15.88M  41.9MB/s    in 0.4s
#
# 2019-06-08 11:52:54 (41.9 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [16648024/16648024]

# %%
# !unzip ngrok-stable-linux-amd64.zip
# Out:
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok

# %%
LOG_DIR = './runs'
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR)
)

# %%
get_ipython().system_raw('./ngrok http 6006 &')

# %%
! curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/usr/lib/python3.6/json/__init__.py", line 299, in load
#     parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#   File "/usr/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
# !ls runs
# Out:
# Jun08_11-46-39_5c6827239b51
